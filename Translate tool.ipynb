# %%
from deep_translator import GoogleTranslator
print("=== Language Transaltion Tool ===")
text = input("Enter text: ")
source_lang = input("Source language (e.g., en): ")
target_lang = input("Target language (e.g., hi): ")
translated = GoogleTranslator(source=source_lang,target=target_lang).translate(text)
print("\nTranslated Text: ")
print(translated)
# Out:
# === Language Transaltion Tool ===
# Enter text:  Hello, what is your ambition
# Source language (e.g., en):  en
# Target language (e.g., hi):  hi
# Translated Text:
# नमस्ते, आपकी महत्वाकांक्षा क्या है?
